# %% [markdown]
# <a href="https://colab.research.google.com/github/sivaranjani098/Data-analytics-project/blob/main/Data_analytics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import a dataset**

# %%
import pandas as pd
data=pd.read_csv('/content/gender_submission.csv')
data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
data.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# **Find the datatypes**

# %%
data.dtypes
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %% [markdown]
# **Find the statistical details**

# %%
data.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]>

# %% [markdown]
# **Removing missing values and outliers**

# %%
data.isnull()
# Out:
#      PassengerId  Survived
# 0          False     False
# 1          False     False
# 2          False     False
# 3          False     False
# 4          False     False
# ..           ...       ...
# 413        False     False
# 414        False     False
# 415        False     False
# 416        False     False
# 417        False     False
#
# [418 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
data.dropna()
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/gender_submission.csv')
df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
plt.figure(figsize=(2,3))
df.plot.box(title='Boxplot')
# Out:
# <Axes: title={'center': 'Boxplot'}>

# %%
plt.figure(figsize=(5,4))
plt.hist(data=data,x='Survived')
plt.title('Survival Rate by Passenger Class and Gender')
plt.show()
